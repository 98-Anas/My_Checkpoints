# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

df = pd.read_csv("titanic-passengers.csv", sep=';')
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['Sex'] = encoder.fit_transform(df['Sex'])
df['Survived'] = encoder.fit_transform(df['Survived'])
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name  Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    1  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    1  25.0      0
# 2                               Jensen, Mr. Hans Peder    1  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.0      0
# 4                               Davidson, Mr. Thornton    1  31.0      1
# ..                                                 ...  ...   ...    ...
# ...

# %%
df['Age'].fillna(df['Age'].mean(),inplace= True)
df_final = df.dropna(axis=1, how= 'any')
df_final
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name  Sex        Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    1  28.000000      0
# 1                              Moen, Mr. Sigurd Hansen    1  25.000000      0
# 2                               Jensen, Mr. Hans Peder    1  20.000000      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.000000      0
# 4                               Davidson, Mr. Thornton    1  31.000000      1
# ...

# %%
plt.title('Passengers Survival')
survived_ppl = df_final['Survived'].value_counts()
survived_ppl.plot.bar(rot= 330)
print('0 : Survived | 1 : non-Survived')
# Out:
# 0 : Survived | 1 : non-Survived

# %%
plt.title("Passenger's Class Survival Representation")
p_class = df_final['Pclass'].value_counts()
p_class.plot.bar(rot= 330)
print('1 : First Class | 2 : Second Class | 3 : Third Class')
# Out:
# 1 : First Class | 2 : Second Class | 3 : Third Class

# %%
df_final['Survived'].corr(df_final['Fare'])
# Out:
# 0.2573065223849624

# %%
df_final['Survived'].corr(df_final['Age'])
# Out:
# -0.06980851528714312

# %%
df['Sex'].corr(df_final['Survived'])
# Out:
# -0.543351380657755

# %%
df_survived = sns.FacetGrid(df_final, col='Survived', row='Sex')
df_survived.map(plt.hist, 'Age', bins=20)
print('Survival = 0 : Survived | 1 : non-Survived')
print('     Sex = 0 : Female   | 1 : Male')
# Out:
# Survival = 0 : Survived | 1 : non-Survived
#      Sex = 0 : Female   | 1 : Male

# %%
df_survived = sns.FacetGrid(df_final, col='Survived', row='Pclass')
df_survived.map(plt.hist, 'Age', bins=20)
print('1 : First Class | 2 : Second Class | 3 : Third Class')
print('Survival = 0 : Survived | 1 : non-Survived')
# Out:
# 1 : First Class | 2 : Second Class | 3 : Third Class
# Survival = 0 : Survived | 1 : non-Survived

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )
plot_correlation_map(df_final)

# %%
df_final[["Survived","Pclass"]].groupby(["Pclass"],as_index=True).mean()
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
def Split(word):
    return [char for char in word]

title = []
for i in range(len(df_final['Name'])):
    L1 = df_final['Name'][i].split()
    for elem in L1 :
        if elem == 'L.':
            continue
        for z in elem :
            if z == '.':
                title.append(elem)
    

title_dic = {'Title1': title}
t_df = pd.DataFrame(title_dic)
new_df = pd.concat([t_df,df_final],axis=1)
new_df
# Out:
#     Title1  PassengerId  Survived  Pclass  \
# 0      Mr.          343         0       2
# 1      Mr.           76         0       3
# 2      Mr.          641         0       3
# 3     Mrs.          568         0       3
# 4      Mr.          672         0       1
# ..     ...          ...       ...     ...
# 886   Mrs.           10         1       2
# 887    Mr.           61         0       3
# 888  Miss.          535         0       3
# 889    Mr.          102         0       3
# 890  Miss.          428         1       2
#
#                                                   Name  Sex        Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    1  28.000000      0
# 1                              Moen, Mr. Sigurd Hansen    1  25.000000      0
# 2                               Jensen, Mr. Hans Peder    1  20.000000      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.000000      0
# ...

# %%
Last_List = []
for i in range(len(new_df['Title1'])):
    Last_List.append(new_df['Title1'][i].split('.')[0])
Last_dic = {'Title': Last_List}
L_df = pd.DataFrame(Last_dic)
Last_df = pd.concat([L_df,new_df],axis=1)
Last_df = Last_df.drop('Title1', axis=1)
Last_df
# Out:
#     Title  PassengerId  Survived  Pclass  \
# 0      Mr          343         0       2
# 1      Mr           76         0       3
# 2      Mr          641         0       3
# 3     Mrs          568         0       3
# 4      Mr          672         0       1
# ..    ...          ...       ...     ...
# 886   Mrs           10         1       2
# 887    Mr           61         0       3
# 888  Miss          535         0       3
# 889    Mr          102         0       3
# 890  Miss          428         1       2
#
#                                                   Name  Sex        Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    1  28.000000      0
# 1                              Moen, Mr. Sigurd Hansen    1  25.000000      0
# 2                               Jensen, Mr. Hans Peder    1  20.000000      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.000000      0
# ...

# %%
# Correlation between Title and Sex in relation to Survival of passenger
Corr = sns.FacetGrid(Last_df, col="Title", row="Sex")
Corr.map(sns.histplot, "Survived")
print('Survival = 0 : Survived | 1 : non-Survived')
print('     Sex = 0 : Female   | 1 : Male')
# Out:
# Survival = 0 : Survived | 1 : non-Survived
#      Sex = 0 : Female   | 1 : Male

# %%
Title_Dictionary = {

                    "Capt":       "Officer",

                    "Col":        "Officer",

                    "Major":      "Officer",

                      "Dr":         "Officer",

                    "Rev":        "Officer",

                    "Jonkheer":   "Royalty",

                    "Don":        "Royalty",

                    "Sir" :       "Royalty",

                   "Lady" :      "Royalty",

                  "the Countess": "Royalty",

                    "Dona":       "Royalty",

                    "Mme":        "Miss",

                    "Mlle":       "Miss",

                    "Miss" :      "Miss",

                    "Ms":         "Mrs",

                    "Mr" :        "Mrs",

                    "Mrs" :       "Mrs",

                    "Master" :    "Master"

                    }
title_replace = {"Title":Title_Dictionary}
final = Last_df.replace(title_replace)

# %%
# Correlation between Title and Sex in relation to Survival of passenger
c = sns.FacetGrid(final, col="Title", row="Sex")
c.map(sns.histplot, "Survived")
print('Survival = 0 : Survived | 1 : non-Survived')
print('     Sex = 0 : Female   | 1 : Male')
# Out:
# Survival = 0 : Survived | 1 : non-Survived
#      Sex = 0 : Female   | 1 : Male

# %%
x = df_final["SibSp"] + df_final["Parch"]
df_final["FamilySize"] = x
df_final["FamilySize"].plot.hist()
# Out:
# <ipython-input-27-736d2ea88763>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["FamilySize"] = x
# <AxesSubplot:ylabel='Frequency'>

# %%
df_final.corr()["FamilySize"]
# Out:
# PassengerId   -0.040143
# Survived       0.016639
# Pclass         0.065997
# Sex           -0.200988
# Age           -0.248512
# SibSp          0.890712
# Parch          0.783111
# Fare           0.217138
# FamilySize     1.000000
# Name: FamilySize, dtype: float64
